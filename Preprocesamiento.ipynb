# %%
import numpy as np
import pandas as pd

# %%
fun_facts = pd.read_excel("data_prueba/DBPlaces.xlsx", sheet_name=3)
fun_facts
# Out:
#       ID                                 touristic_place_id  \
# 0      1                                        BAR CORDANO
# 1      2                                        BAR CORDANO
# 2      3                                        BAR CORDANO
# 3      4                             PALACIO DE TORRE TAGLE
# 4      5                             PALACIO DE TORRE TAGLE
# 5      6                             PALACIO DE TORRE TAGLE
# 6      7                              MUSEO DE ARTE DE LIMA
# 7      8                              MUSEO DE ARTE DE LIMA
# 8      9                              MUSEO DE ARTE DE LIMA
# 9     10  MUSEO HISTORICO MILITAR DE LOS COMBATIENTES DE...
# 10    11  MUSEO HISTORICO MILITAR DE LOS COMBATIENTES DE...
# 11    12                               PARQUE UNIVERSITARIO
# 12    13                               PARQUE UNIVERSITARIO
# 13    14                               PARQUE UNIVERSITARIO
# 14    15  MUSEO DE LA INQUISICIÓN Y DEL CONGRESO DE LA R...
# ...
